# %% [markdown]
# # Problem loading FCC newstyle samples

# %% [markdown]
# - ### The FCC Simulation samples using 'New-style EDM4HEP' have a non-interpretable branch called `PARAMETERS` that derives from `podio::GenericParameters`
# - ### Not able to load them with coffea in delayed mode

# %% [markdown]
# - ### Eager mode works
# It Skips the non-interpretable branches

# %%
test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
from coffea.nanoevents import NanoEventsFactory, BaseSchema
events = NanoEventsFactory.from_root(
test_file+":events",
    entry_stop=100,
    schemaclass=BaseSchema,
    delayed = False
).events()
# Out:
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_intMap/_intMap.first as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_intMap/_intMap.second as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_floatMap/_floatMap.first as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_floatMap/_floatMap.second as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_stringMap/_stringMap.first as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_stringMap/_stringMap.second as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_doubleMap/_doubleMap.first as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")
# /home/prayag/coffeafcc/development/coffea/src/coffea/nanoevents/mapping/uproot.py:144: UserWarning: Skipping PARAMETERS/_doubleMap/_doubleMap.second as it is not interpretable by Uproot
#   warnings.warn(f"Skipping {key} as it is not interpretable by Uproot")

# %%
events.fields
# Out:
# ['CalorimeterHits/CalorimeterHits.cellID',
#  'CalorimeterHits/CalorimeterHits.energy',
#  'CalorimeterHits/CalorimeterHits.energyError',
#  'CalorimeterHits/CalorimeterHits.time',
#  'CalorimeterHits/CalorimeterHits.position.x',
#  'CalorimeterHits/CalorimeterHits.position.y',
#  'CalorimeterHits/CalorimeterHits.position.z',
#  'CalorimeterHits/CalorimeterHits.type',
#  'EFlowNeutralHadron/EFlowNeutralHadron.type',
#  'EFlowNeutralHadron/EFlowNeutralHadron.energy',
#  'EFlowNeutralHadron/EFlowNeutralHadron.energyError',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.x',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.y',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.z',
#  'EFlowNeutralHadron/EFlowNeutralHadron.positionError[6]',
#  'EFlowNeutralHadron/EFlowNeutralHadron.iTheta',
#  'EFlowNeutralHadron/EFlowNeutralHadron.phi',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.x',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.y',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.z',
#  'EFlowNeutralHadron/EFlowNeutralHadron.shapeParameters_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.shapeParameters_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.subdetectorEnergies_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.subdetectorEnergies_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.clusters_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.clusters_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.hits_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.hits_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.particleIDs_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.particleIDs_end',
#  '_EFlowNeutralHadron_clusters/_EFlowNeutralHadron_clusters.index',
#  '_EFlowNeutralHadron_clusters/_EFlowNeutralHadron_clusters.collectionID',
#  '_EFlowNeutralHadron_hits/_EFlowNeutralHadron_hits.index',
#  '_EFlowNeutralHadron_hits/_EFlowNeutralHadron_hits.collectionID',
#  '_EFlowNeutralHadron_particleIDs/_EFlowNeutralHadron_particleIDs.index',
#  '_EFlowNeutralHadron_particleIDs/_EFlowNeutralHadron_particleIDs.collectionID',
#  '_EFlowNeutralHadron_shapeParameters',
#  '_EFlowNeutralHadron_subdetectorEnergies',
#  'EFlowPhoton/EFlowPhoton.type',
#  'EFlowPhoton/EFlowPhoton.energy',
#  'EFlowPhoton/EFlowPhoton.energyError',
#  'EFlowPhoton/EFlowPhoton.position.x',
#  'EFlowPhoton/EFlowPhoton.position.y',
#  'EFlowPhoton/EFlowPhoton.position.z',
#  'EFlowPhoton/EFlowPhoton.positionError[6]',
#  'EFlowPhoton/EFlowPhoton.iTheta',
#  'EFlowPhoton/EFlowPhoton.phi',
#  'EFlowPhoton/EFlowPhoton.directionError.x',
#  'EFlowPhoton/EFlowPhoton.directionError.y',
#  'EFlowPhoton/EFlowPhoton.directionError.z',
#  'EFlowPhoton/EFlowPhoton.shapeParameters_begin',
#  'EFlowPhoton/EFlowPhoton.shapeParameters_end',
#  'EFlowPhoton/EFlowPhoton.subdetectorEnergies_begin',
#  'EFlowPhoton/EFlowPhoton.subdetectorEnergies_end',
#  'EFlowPhoton/EFlowPhoton.clusters_begin',
#  'EFlowPhoton/EFlowPhoton.clusters_end',
#  'EFlowPhoton/EFlowPhoton.hits_begin',
#  'EFlowPhoton/EFlowPhoton.hits_end',
#  'EFlowPhoton/EFlowPhoton.particleIDs_begin',
#  'EFlowPhoton/EFlowPhoton.particleIDs_end',
#  '_EFlowPhoton_clusters/_EFlowPhoton_clusters.index',
#  '_EFlowPhoton_clusters/_EFlowPhoton_clusters.collectionID',
#  '_EFlowPhoton_hits/_EFlowPhoton_hits.index',
#  '_EFlowPhoton_hits/_EFlowPhoton_hits.collectionID',
#  '_EFlowPhoton_particleIDs/_EFlowPhoton_particleIDs.index',
#  '_EFlowPhoton_particleIDs/_EFlowPhoton_particleIDs.collectionID',
#  '_EFlowPhoton_shapeParameters',
#  '_EFlowPhoton_subdetectorEnergies',
#  'EFlowTrack/EFlowTrack.type',
#  'EFlowTrack/EFlowTrack.chi2',
#  'EFlowTrack/EFlowTrack.ndf',
#  'EFlowTrack/EFlowTrack.dEdx',
#  'EFlowTrack/EFlowTrack.dEdxError',
#  'EFlowTrack/EFlowTrack.radiusOfInnermostHit',
#  'EFlowTrack/EFlowTrack.subdetectorHitNumbers_begin',
#  'EFlowTrack/EFlowTrack.subdetectorHitNumbers_end',
#  'EFlowTrack/EFlowTrack.trackStates_begin',
#  'EFlowTrack/EFlowTrack.trackStates_end',
#  'EFlowTrack/EFlowTrack.dxQuantities_begin',
#  'EFlowTrack/EFlowTrack.dxQuantities_end',
#  'EFlowTrack/EFlowTrack.trackerHits_begin',
#  'EFlowTrack/EFlowTrack.trackerHits_end',
#  'EFlowTrack/EFlowTrack.tracks_begin',
#  'EFlowTrack/EFlowTrack.tracks_end',
#  '_EFlowTrack_trackerHits/_EFlowTrack_trackerHits.index',
#  '_EFlowTrack_trackerHits/_EFlowTrack_trackerHits.collectionID',
#  '_EFlowTrack_tracks/_EFlowTrack_tracks.index',
#  '_EFlowTrack_tracks/_EFlowTrack_tracks.collectionID',
#  '_EFlowTrack_subdetectorHitNumbers',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.location',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.D0',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.phi',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.omega',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.Z0',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.tanLambda',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.time',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.x',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.y',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.z',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.covMatrix[21]',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.type',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.value',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.error',
#  'EFlowTrack_L',
#  'Electron_objIdx/Electron_objIdx.index',
#  'Electron_objIdx/Electron_objIdx.collectionID',
#  'Electron_IsolationVar',
#  'EventHeader/EventHeader.eventNumber',
#  'EventHeader/EventHeader.runNumber',
#  'EventHeader/EventHeader.timeStamp',
#  'EventHeader/EventHeader.weight',
#  'Jet/Jet.type',
#  'Jet/Jet.energy',
#  'Jet/Jet.momentum.x',
#  'Jet/Jet.momentum.y',
#  'Jet/Jet.momentum.z',
#  'Jet/Jet.referencePoint.x',
#  'Jet/Jet.referencePoint.y',
#  'Jet/Jet.referencePoint.z',
#  'Jet/Jet.charge',
#  'Jet/Jet.mass',
#  'Jet/Jet.goodnessOfPID',
#  'Jet/Jet.covMatrix[10]',
#  'Jet/Jet.clusters_begin',
#  'Jet/Jet.clusters_end',
#  'Jet/Jet.tracks_begin',
#  'Jet/Jet.tracks_end',
#  'Jet/Jet.particles_begin',
#  'Jet/Jet.particles_end',
#  'Jet/Jet.particleIDs_begin',
#  'Jet/Jet.particleIDs_end',
#  '_Jet_clusters/_Jet_clusters.index',
#  '_Jet_clusters/_Jet_clusters.collectionID',
#  '_Jet_tracks/_Jet_tracks.index',
#  '_Jet_tracks/_Jet_tracks.collectionID',
#  '_Jet_particles/_Jet_particles.index',
#  '_Jet_particles/_Jet_particles.collectionID',
#  '_Jet_particleIDs/_Jet_particleIDs.index',
#  '_Jet_particleIDs/_Jet_particleIDs.collectionID',
#  '_Jet_startVertex/_Jet_startVertex.index',
#  '_Jet_startVertex/_Jet_startVertex.collectionID',
#  '_Jet_particleIDUsed/_Jet_particleIDUsed.index',
#  '_Jet_particleIDUsed/_Jet_particleIDUsed.collectionID',
#  'magFieldBz',
#  'MCRecoAssociations/MCRecoAssociations.weight',
#  '_MCRecoAssociations_rec/_MCRecoAssociations_rec.index',
#  '_MCRecoAssociations_rec/_MCRecoAssociations_rec.collectionID',
#  '_MCRecoAssociations_sim/_MCRecoAssociations_sim.index',
#  '_MCRecoAssociations_sim/_MCRecoAssociations_sim.collectionID',
#  'Muon_objIdx/Muon_objIdx.index',
#  'Muon_objIdx/Muon_objIdx.collectionID',
#  'Muon_IsolationVar',
#  'Particle/Particle.PDG',
#  'Particle/Particle.generatorStatus',
#  'Particle/Particle.simulatorStatus',
#  'Particle/Particle.charge',
#  'Particle/Particle.time',
#  'Particle/Particle.mass',
#  'Particle/Particle.vertex.x',
#  'Particle/Particle.vertex.y',
#  'Particle/Particle.vertex.z',
#  'Particle/Particle.endpoint.x',
#  'Particle/Particle.endpoint.y',
#  'Particle/Particle.endpoint.z',
#  'Particle/Particle.momentum.x',
#  'Particle/Particle.momentum.y',
#  'Particle/Particle.momentum.z',
#  'Particle/Particle.momentumAtEndpoint.x',
#  'Particle/Particle.momentumAtEndpoint.y',
#  'Particle/Particle.momentumAtEndpoint.z',
#  'Particle/Particle.spin.x',
#  'Particle/Particle.spin.y',
#  'Particle/Particle.spin.z',
#  'Particle/Particle.colorFlow.a',
#  'Particle/Particle.colorFlow.b',
#  'Particle/Particle.parents_begin',
#  'Particle/Particle.parents_end',
#  'Particle/Particle.daughters_begin',
#  'Particle/Particle.daughters_end',
#  '_Particle_parents/_Particle_parents.index',
#  '_Particle_parents/_Particle_parents.collectionID',
#  '_Particle_daughters/_Particle_daughters.index',
#  '_Particle_daughters/_Particle_daughters.collectionID',
#  'ParticleIDs/ParticleIDs.type',
#  'ParticleIDs/ParticleIDs.PDG',
#  'ParticleIDs/ParticleIDs.algorithmType',
#  'ParticleIDs/ParticleIDs.likelihood',
#  'ParticleIDs/ParticleIDs.parameters_begin',
#  'ParticleIDs/ParticleIDs.parameters_end',
#  '_ParticleIDs_parameters',
#  'Photon_objIdx/Photon_objIdx.index',
#  'Photon_objIdx/Photon_objIdx.collectionID',
#  'Photon_IsolationVar',
#  'ReconstructedParticles/ReconstructedParticles.type',
#  'ReconstructedParticles/ReconstructedParticles.energy',
#  'ReconstructedParticles/ReconstructedParticles.momentum.x',
#  'ReconstructedParticles/ReconstructedParticles.momentum.y',
#  'ReconstructedParticles/ReconstructedParticles.momentum.z',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.x',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.y',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.z',
#  'ReconstructedParticles/ReconstructedParticles.charge',
#  'ReconstructedParticles/ReconstructedParticles.mass',
#  'ReconstructedParticles/ReconstructedParticles.goodnessOfPID',
#  'ReconstructedParticles/ReconstructedParticles.covMatrix[10]',
#  'ReconstructedParticles/ReconstructedParticles.clusters_begin',
#  'ReconstructedParticles/ReconstructedParticles.clusters_end',
#  'ReconstructedParticles/ReconstructedParticles.tracks_begin',
#  'ReconstructedParticles/ReconstructedParticles.tracks_end',
#  'ReconstructedParticles/ReconstructedParticles.particles_begin',
#  'ReconstructedParticles/ReconstructedParticles.particles_end',
#  'ReconstructedParticles/ReconstructedParticles.particleIDs_begin',
#  'ReconstructedParticles/ReconstructedParticles.particleIDs_end',
#  '_ReconstructedParticles_clusters/_ReconstructedParticles_clusters.index',
#  '_ReconstructedParticles_clusters/_ReconstructedParticles_clusters.collectionID',
#  '_ReconstructedParticles_tracks/_ReconstructedParticles_tracks.index',
#  '_ReconstructedParticles_tracks/_ReconstructedParticles_tracks.collectionID',
#  '_ReconstructedParticles_particles/_ReconstructedParticles_particles.index',
#  '_ReconstructedParticles_particles/_ReconstructedParticles_particles.collectionID',
#  '_ReconstructedParticles_particleIDs/_ReconstructedParticles_particleIDs.index',
#  '_ReconstructedParticles_particleIDs/_ReconstructedParticles_particleIDs.collectionID',
#  '_ReconstructedParticles_startVertex/_ReconstructedParticles_startVertex.index',
#  '_ReconstructedParticles_startVertex/_ReconstructedParticles_startVertex.collectionID',
#  '_ReconstructedParticles_particleIDUsed/_ReconstructedParticles_particleIDUsed.index',
#  '_ReconstructedParticles_particleIDUsed/_ReconstructedParticles_particleIDUsed.collectionID',
#  'TrackerHits/TrackerHits.cellID',
#  'TrackerHits/TrackerHits.type',
#  'TrackerHits/TrackerHits.quality',
#  'TrackerHits/TrackerHits.time',
#  'TrackerHits/TrackerHits.eDep',
#  'TrackerHits/TrackerHits.eDepError',
#  'TrackerHits/TrackerHits.position.x',
#  'TrackerHits/TrackerHits.position.y',
#  'TrackerHits/TrackerHits.position.z',
#  'TrackerHits/TrackerHits.covMatrix[6]',
#  'TrackerHits/TrackerHits.rawHits_begin',
#  'TrackerHits/TrackerHits.rawHits_end',
#  '_TrackerHits_rawHits/_TrackerHits_rawHits.index',
#  '_TrackerHits_rawHits/_TrackerHits_rawHits.collectionID']

# %% [markdown]
# - ### uproot.open() works
#   uproot does'nt recognize the `PARAMETERS` branches

# %%
og = uproot.open(test_file+":events")
og.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# CalorimeterHits      | vector<edm4hep::Calor... | AsGroup(<TBranchElement 'Ca...
# CalorimeterHits/C... | uint64_t[]               | AsJagged(AsDtype('>u8'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | float[]                  | AsJagged(AsDtype('>f4'))
# CalorimeterHits/C... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EFlowNeutralHadron   | vector<edm4hep::Clust... | AsGroup(<TBranchElement 'EF...
# EFlowNeutralHadro... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[][6]               | AsJagged(AsDtype("('>f4', (...
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowNeutralHadro... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowNeutralHadr... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowNeutralHadr... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowNeutralHadr... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowNeutralHadr... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowNeutralHadr... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowNeutralHadr... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowNeutralHadr... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowNeutralHadr... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowNeutralHadr... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowNeutralHadr... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# _EFlowNeutralHadr... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# EFlowPhoton          | vector<edm4hep::Clust... | AsGroup(<TBranchElement 'EF...
# EFlowPhoton/EFlow... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[][6]               | AsJagged(AsDtype("('>f4', (...
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowPhoton/EFlow... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowPhoton_clus... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowPhoton_clus... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowPhoton_clus... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowPhoton_hits    | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowPhoton_hits... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowPhoton_hits... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowPhoton_part... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowPhoton_part... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowPhoton_part... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowPhoton_shap... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# _EFlowPhoton_subd... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# EFlowTrack           | vector<edm4hep::Track... | AsGroup(<TBranchElement 'EF...
# EFlowTrack/EFlowT... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EFlowTrack/EFlowT... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowTrack/EFlowT... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EFlowTrack/EFlowT... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowTrack/EFlowT... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowTrack/EFlowT... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# EFlowTrack/EFlowT... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowTrack_track... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowTrack_track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowTrack_track... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowTrack_tracks   | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_E...
# _EFlowTrack_track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowTrack_track... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _EFlowTrack_subde... | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# _EFlowTrack_track... | vector<edm4hep::Track... | AsGroup(<TBranchElement '_E...
# _EFlowTrack_track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_track... | float[][21]              | AsJagged(AsDtype("('>f4', (...
# _EFlowTrack_dxQua... | vector<edm4hep::Quant... | AsGroup(<TBranchElement '_E...
# _EFlowTrack_dxQua... | int16_t[]                | AsJagged(AsDtype('>i2'))
# _EFlowTrack_dxQua... | float[]                  | AsJagged(AsDtype('>f4'))
# _EFlowTrack_dxQua... | float[]                  | AsJagged(AsDtype('>f4'))
# EFlowTrack_L         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# Electron_objIdx      | vector<podio::ObjectID>  | AsGroup(<TBranchElement 'El...
# Electron_objIdx/E... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Electron_objIdx/E... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Electron_Isolatio... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# EventHeader          | vector<edm4hep::Event... | AsGroup(<TBranchElement 'Ev...
# EventHeader/Event... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EventHeader/Event... | int32_t[]                | AsJagged(AsDtype('>i4'))
# EventHeader/Event... | uint64_t[]               | AsJagged(AsDtype('>u8'))
# EventHeader/Event... | float[]                  | AsJagged(AsDtype('>f4'))
# Jet                  | vector<edm4hep::Recon... | AsGroup(<TBranchElement 'Je...
# Jet/Jet.type         | int32_t[]                | AsJagged(AsDtype('>i4'))
# Jet/Jet.energy       | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.momentum.x   | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.momentum.y   | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.momentum.z   | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.reference... | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.reference... | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.reference... | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.charge       | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.mass         | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.goodnessO... | float[]                  | AsJagged(AsDtype('>f4'))
# Jet/Jet.covMatrix... | float[][10]              | AsJagged(AsDtype("('>f4', (...
# Jet/Jet.clusters_... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.clusters_end | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.tracks_begin | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.tracks_end   | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.particles... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.particles... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.particleI... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Jet/Jet.particleI... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_clusters        | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_clusters/_Je... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_clusters/_Je... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_tracks          | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_tracks/_Jet_... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_tracks/_Jet_... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_particles       | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_particles/_J... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_particles/_J... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_particleIDs     | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_particleIDs/... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_particleIDs/... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_startVertex     | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_startVertex/... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_startVertex/... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Jet_particleIDUsed  | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_J...
# _Jet_particleIDUs... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Jet_particleIDUs... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# magFieldBz           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# MCRecoAssociations   | vector<edm4hep::MCRec... | AsGroup(<TBranchElement 'MC...
# MCRecoAssociation... | float[]                  | AsJagged(AsDtype('>f4'))
# _MCRecoAssociatio... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_M...
# _MCRecoAssociatio... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _MCRecoAssociatio... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _MCRecoAssociatio... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_M...
# _MCRecoAssociatio... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _MCRecoAssociatio... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Muon_objIdx          | vector<podio::ObjectID>  | AsGroup(<TBranchElement 'Mu...
# Muon_objIdx/Muon_... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Muon_objIdx/Muon_... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Muon_IsolationVar    | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# Particle             | vector<edm4hep::MCPar... | AsGroup(<TBranchElement 'Pa...
# Particle/Particle... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Particle/Particle... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Particle/Particle... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | double[]                 | AsJagged(AsDtype('>f8'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | float[]                  | AsJagged(AsDtype('>f4'))
# Particle/Particle... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Particle/Particle... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Particle/Particle... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Particle/Particle... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Particle/Particle... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Particle/Particle... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Particle_parents    | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_P...
# _Particle_parents... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Particle_parents... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _Particle_daughters  | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_P...
# _Particle_daughte... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _Particle_daughte... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ParticleIDs          | vector<edm4hep::Parti... | AsGroup(<TBranchElement 'Pa...
# ParticleIDs/Parti... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ParticleIDs/Parti... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ParticleIDs/Parti... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ParticleIDs/Parti... | float[]                  | AsJagged(AsDtype('>f4'))
# ParticleIDs/Parti... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ParticleIDs/Parti... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ParticleIDs_para... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# Photon_objIdx        | vector<podio::ObjectID>  | AsGroup(<TBranchElement 'Ph...
# Photon_objIdx/Pho... | int32_t[]                | AsJagged(AsDtype('>i4'))
# Photon_objIdx/Pho... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# Photon_IsolationVar  | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ReconstructedPart... | vector<edm4hep::Recon... | AsGroup(<TBranchElement 'Re...
# ReconstructedPart... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[]                  | AsJagged(AsDtype('>f4'))
# ReconstructedPart... | float[][10]              | AsJagged(AsDtype("('>f4', (...
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# ReconstructedPart... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _ReconstructedPar... | vector<podio::ObjectID>  | AsGroup(<TBranchElement '_R...
# _ReconstructedPar... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _ReconstructedPar... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# TrackerHits          | vector<edm4hep::Track... | AsGroup(<TBranchElement 'Tr...
# TrackerHits/Track... | uint64_t[]               | AsJagged(AsDtype('>u8'))
# TrackerHits/Track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# TrackerHits/Track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# TrackerHits/Track... | float[]                  | AsJagged(AsDtype('>f4'))
# TrackerHits/Track... | float[]                  | AsJagged(AsDtype('>f4'))
# TrackerHits/Track... | float[]                  | AsJagged(AsDtype('>f4'))
# TrackerHits/Track... | double[]                 | AsJagged(AsDtype('>f8'))
# TrackerHits/Track... | double[]                 | AsJagged(AsDtype('>f8'))
# TrackerHits/Track... | double[]                 | AsJagged(AsDtype('>f8'))
# TrackerHits/Track... | float[][6]               | AsJagged(AsDtype("('>f4', (...
# TrackerHits/Track... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# TrackerHits/Track... | uint32_t[]               | AsJagged(AsDtype('>u4'))
# _TrackerHits_rawHits | vector<edm4hep::Objec... | AsGroup(<TBranchElement '_T...
# _TrackerHits_rawH... | int32_t[]                | AsJagged(AsDtype('>i4'))
# _TrackerHits_rawH... | int32_t[]                | AsJagged(AsDtype('>i4'))
# PARAMETERS           | podio::GenericParameters | AsGroup(<TBranchElement 'PA...
# PARAMETERS/_intMap   | map<string,vector<int> > | AsGroup(<TBranchElement '_i...
# PARAMETERS/_intMa... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_intMa... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_floatMap | map<string,vector<flo... | AsGroup(<TBranchElement '_f...
# PARAMETERS/_float... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_float... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_strin... | map<string,vector<str... | AsGroup(<TBranchElement '_s...
# PARAMETERS/_strin... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_strin... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_doubl... | map<string,vector<dou... | AsGroup(<TBranchElement '_d...
# PARAMETERS/_doubl... | unknown                  | <UnknownInterpretation 'non...
# PARAMETERS/_doubl... | unknown                  | <UnknownInterpretation 'non...

# %%
p = og["PARAMETERS"]
p.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# PARAMETERS           | podio::GenericParameters | AsGroup(<TBranchElement 'PARAM
# _intMap              | map<string,vector<int> > | AsGroup(<TBranchElement '_i...
# _intMap/_intMap.f... | unknown                  | <UnknownInterpretation 'non...
# _intMap/_intMap.s... | unknown                  | <UnknownInterpretation 'non...
# _floatMap            | map<string,vector<flo... | AsGroup(<TBranchElement '_f...
# _floatMap/_floatM... | unknown                  | <UnknownInterpretation 'non...
# _floatMap/_floatM... | unknown                  | <UnknownInterpretation 'non...
# _stringMap           | map<string,vector<str... | AsGroup(<TBranchElement '_s...
# _stringMap/_strin... | unknown                  | <UnknownInterpretation 'non...
# _stringMap/_strin... | unknown                  | <UnknownInterpretation 'non...
# _doubleMap           | map<string,vector<dou... | AsGroup(<TBranchElement '_d...
# _doubleMap/_doubl... | unknown                  | <UnknownInterpretation 'non...
# _doubleMap/_doubl... | unknown                  | <UnknownInterpretation 'non...

# %%
map = p["_intMap"]
map.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# _intMap              | map<string,vector<int> > | AsGroup(<TBranchElement '_intM
# _intMap.first        | unknown                  | <UnknownInterpretation 'non...
# _intMap.second       | unknown                  | <UnknownInterpretation 'non...

# %%
map["_intMap.first"].interpretation
# Out:
# <UnknownInterpretation 'none of the rules matched'>

# %% [markdown]
# - ### Delayed Mode in coffea doesn't work

# %%
test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
from coffea.nanoevents import NanoEventsFactory, BaseSchema
events = NanoEventsFactory.from_root(
test_file+":events",
    entry_stop=100,
    schemaclass=BaseSchema,
    delayed = True
).events()
# Out:
# ---------------------------------------------------------------------------
# UnknownInterpretation                     Traceback (most recent call last)
# Cell In[23], line 8
#       1 test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
#       2 from coffea.nanoevents import NanoEventsFactory, BaseSchema
#       3 events = NanoEventsFactory.from_root(
#       4 test_file+":events",
#       5     entry_stop=100,
#       6     schemaclass=BaseSchema,
#       7     delayed = True
# ----> 8 ).events()
#
# File ~/coffeafcc/development/coffea/src/coffea/nanoevents/factory.py:684, in NanoEventsFactory.events(self)
#     682 """Build events"""
#     683 if self._is_dask:
# --> 684     events = self._mapping(form_mapping=self._schema)
#     685     report = None
#     686     if isinstance(events, tuple):
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/_dask.py:296, in dask(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, steps_per_file, library, ak_add_doc, custom_classes, allow_missing, open_files, form_mapping, allow_read_errors_with_report, known_base_form, decompression_executor, interpretation_executor, **options)
#     277         return _get_dak_array(
#     278             files,
#     279             filter_name,
#    (...)
#     293             interpretation_executor,
#     294         )
#     295     else:
# --> 296         return _get_dak_array_delay_open(
#     297             files,
#     298             filter_name,
#     299             filter_typename,
#     300             filter_branch,
#     301             recursive,
#     302             full_paths,
#     303             custom_classes,
#     304             allow_missing,
#     305             real_options,
#     306             interp_options,
#     307             form_mapping,
#     308             steps_per_file,
#     309             allow_read_errors_with_report,
#     310             known_base_form,
#     311             decompression_executor,
#     312             interpretation_executor,
#     313         )
#     314 else:
#     315     raise NotImplementedError()
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/_dask.py:1598, in _get_dak_array_delay_open(files, filter_name, filter_typename, filter_branch, recursive, full_paths, custom_classes, allow_missing, real_options, interp_options, form_mapping, steps_per_file, allow_read_errors_with_report, known_base_form, decompression_executor, interpretation_executor)
#    1594 else:
#    1595     obj = uproot._util.regularize_object_path(
#    1596         ffile_path, fobject_path, custom_classes, allow_missing, real_options
#    1597     )
# -> 1598     common_keys = obj.keys(
#    1599         recursive=recursive,
#    1600         filter_name=filter_name,
#    1601         filter_typename=filter_typename,
#    1602         filter_branch=filter_branch,
#    1603         full_paths=full_paths,
#    1604         ignore_duplicates=True,
#    1605     )
#    1606     base_form = _get_ttree_form(
#    1607         awkward, obj, common_keys, interp_options.get("ak_add_doc")
#    1608     )
#    1610 divisions = [0]
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/behaviors/TBranch.py:1157, in HasBranches.keys(self, filter_name, filter_typename, filter_branch, recursive, full_paths, ignore_duplicates)
#    1127 def keys(
#    1128     self,
#    1129     *,
#    (...)
#    1135     ignore_duplicates=False,
#    1136 ):
#    1137     """
#    1138     Args:
#    1139         filter_name (None, glob string, regex string in ``"/pattern/i"`` syntax, function of str \u2192 bool, or iterable of the above): A
#    (...)
#    1155     Returns the names of the subbranches as a list of strings.
#    1156     """
# -> 1157     return list(
#    1158         self.iterkeys(
#    1159             filter_name=filter_name,
#    1160             filter_typename=filter_typename,
#    1161             filter_branch=filter_branch,
#    1162             recursive=recursive,
#    1163             full_paths=full_paths,
#    1164             ignore_duplicates=ignore_duplicates,
#    1165         )
#    1166     )
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/behaviors/TBranch.py:1314, in HasBranches.iterkeys(self, filter_name, filter_typename, filter_branch, recursive, full_paths, ignore_duplicates)
#    1283 def iterkeys(
#    1284     self,
#    1285     *,
#    (...)
#    1291     ignore_duplicates=False,
#    1292 ):
#    1293     """
#    1294     Args:
#    1295         filter_name (None, glob string, regex string in ``"/pattern/i"`` syntax, function of str \u2192 bool, or iterable of the above): A
#    (...)
#    1312     Returns the names of the subbranches as an iterator over strings.
#    1313     """
# -> 1314     for k, _ in self.iteritems(
#    1315         filter_name=filter_name,
#    1316         filter_typename=filter_typename,
#    1317         filter_branch=filter_branch,
#    1318         recursive=recursive,
#    1319         full_paths=full_paths,
#    1320         ignore_duplicates=ignore_duplicates,
#    1321     ):
#    1322         yield k
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/behaviors/TBranch.py:1413, in HasBranches.iteritems(self, filter_name, filter_typename, filter_branch, recursive, full_paths, ignore_duplicates)
#    1404 keys_set = set()
#    1406 for branch in self.branches:
#    1407     if (
#    1408         (
#    1409             filter_name is no_filter
#    1410             or _filter_name_deep(filter_name, self, branch)
#    1411         )
#    1412         and (filter_typename is no_filter or filter_typename(branch.typename))
# -> 1413         and (filter_branch is no_filter or filter_branch(branch))
#    1414     ):
#    1415         if ignore_duplicates and branch.name in keys_set:
#    1416             pass
#
# File ~/coffeafcc/development/coffea/src/coffea/util.py:240, in _remove_not_interpretable(branch, emit_warning)
#     237     return False
#     239 try:
# --> 240     _ = branch.interpretation.awkward_form(None)
#     241 except uproot.interpretation.objects.CannotBeAwkward:
#     242     if emit_warning:
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/grouped.py:105, in AsGrouped.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#     103     if y is not None:
#     104         names.append(x)
# --> 105         fields.append(y.awkward_form(file, context))
#     106 return awkward.forms.RecordForm(fields, names)
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/grouped.py:105, in AsGrouped.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#     103     if y is not None:
#     104         names.append(x)
# --> 105         fields.append(y.awkward_form(file, context))
#     106 return awkward.forms.RecordForm(fields, names)
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/identify.py:1195, in UnknownInterpretation.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#    1186 def awkward_form(
#    1187     self,
#    1188     file,
#    (...)
#    1193     breadcrumbs=(),
#    1194 ):
# -> 1195     raise self
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/behaviors/TBranch.py:1932, in TBranch.interpretation(self)
#    1930 if self._interpretation is None:
#    1931     try:
# -> 1932         self._interpretation = uproot.interpretation.identify.interpretation_of(
#    1933             self, {}
#    1934         )
#    1935     except uproot.interpretation.identify.UnknownInterpretation as err:
#    1936         self._interpretation = err
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/identify.py:507, in interpretation_of(branch, context, simplify)
#     504         else:
#     505             return out
# --> 507 raise UnknownInterpretation(
#     508     "none of the rules matched",
#     509     branch.file.file_path,
#     510     branch.object_path,
#     511 )
#
# UnknownInterpretation: none of the rules matched
# in file ./p8_ee_ZZ_ecm240_edm4hep.root
# in object /events;1:PARAMETERS/_intMap/_intMap.first

# %% [markdown]
# - ### uproot.dask doesn't work

# %%
import uproot
test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
events = uproot.dask(test_file+":events")
# Out:
# ---------------------------------------------------------------------------
# UnknownInterpretation                     Traceback (most recent call last)
# Cell In[24], line 3
#       1 import uproot
#       2 test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
# ----> 3 events = uproot.dask(test_file+":events")
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/_dask.py:277, in dask(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, steps_per_file, library, ak_add_doc, custom_classes, allow_missing, open_files, form_mapping, allow_read_errors_with_report, known_base_form, decompression_executor, interpretation_executor, **options)
#     275 elif library.name == "ak":
#     276     if open_files:
# --> 277         return _get_dak_array(
#     278             files,
#     279             filter_name,
#     280             filter_typename,
#     281             filter_branch,
#     282             recursive,
#     283             full_paths,
#     284             step_size,
#     285             custom_classes,
#     286             allow_missing,
#     287             real_options,
#     288             interp_options,
#     289             form_mapping,
#     290             steps_per_file,
#     291             allow_read_errors_with_report,
#     292             decompression_executor,
#     293             interpretation_executor,
#     294         )
#     295     else:
#     296         return _get_dak_array_delay_open(
#     297             files,
#     298             filter_name,
#    (...)
#     312             interpretation_executor,
#     313         )
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/_dask.py:1532, in _get_dak_array(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, custom_classes, allow_missing, real_options, interp_options, form_mapping, steps_per_file, allow_read_errors_with_report, decompression_executor, interpretation_executor)
#    1529                 divisions.append(divisions[-1] + length)
#    1530                 partition_args.append((i, start, stop))
# -> 1532 base_form = _get_ttree_form(
#    1533     awkward, ttrees[0], common_keys, interp_options.get("ak_add_doc")
#    1534 )
#    1536 if len(partition_args) == 0:
#    1537     divisions.append(0)
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/_dask.py:1375, in _get_ttree_form(awkward, ttree, common_keys, ak_add_doc)
#    1373 for key in common_keys:
#    1374     branch = ttree[key]
# -> 1375     content_form = branch.interpretation.awkward_form(ttree.file)
#    1376     if ak_add_doc:
#    1377         content_form = content_form.copy(parameters={"__doc__": branch.title})
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/grouped.py:105, in AsGrouped.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#     103     if y is not None:
#     104         names.append(x)
# --> 105         fields.append(y.awkward_form(file, context))
#     106 return awkward.forms.RecordForm(fields, names)
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/grouped.py:105, in AsGrouped.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#     103     if y is not None:
#     104         names.append(x)
# --> 105         fields.append(y.awkward_form(file, context))
#     106 return awkward.forms.RecordForm(fields, names)
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/identify.py:1195, in UnknownInterpretation.awkward_form(self, file, context, index_format, header, tobject_header, breadcrumbs)
#    1186 def awkward_form(
#    1187     self,
#    1188     file,
#    (...)
#    1193     breadcrumbs=(),
#    1194 ):
# -> 1195     raise self
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/behaviors/TBranch.py:1932, in TBranch.interpretation(self)
#    1930 if self._interpretation is None:
#    1931     try:
# -> 1932         self._interpretation = uproot.interpretation.identify.interpretation_of(
#    1933             self, {}
#    1934         )
#    1935     except uproot.interpretation.identify.UnknownInterpretation as err:
#    1936         self._interpretation = err
#
# File ~/coffeafcc/development/fcc-dev/lib64/python3.12/site-packages/uproot/interpretation/identify.py:507, in interpretation_of(branch, context, simplify)
#     504         else:
#     505             return out
# --> 507 raise UnknownInterpretation(
#     508     "none of the rules matched",
#     509     branch.file.file_path,
#     510     branch.object_path,
#     511 )
#
# UnknownInterpretation: none of the rules matched
# in file ./p8_ee_ZZ_ecm240_edm4hep.root
# in object /events;1:PARAMETERS/_intMap/_intMap.first

# %% [markdown]
# - ### looking through optional parameters of `uproot.dask`
# - Filter branch names containing the string "PARAMETERS"

# %%
test_file = "./p8_ee_ZZ_ecm240_edm4hep.root"
from coffea.nanoevents import NanoEventsFactory, BaseSchema
events = NanoEventsFactory.from_root(
test_file+":events",
    entry_stop=100,
    schemaclass=BaseSchema,
    delayed = True,
    uproot_options={"filter_name": lambda x: "PARAMETERS" not in x}
).events()

# %%
events.fields
# Out:
# ['CalorimeterHits',
#  'CalorimeterHits/CalorimeterHits.cellID',
#  'CalorimeterHits/CalorimeterHits.energy',
#  'CalorimeterHits/CalorimeterHits.energyError',
#  'CalorimeterHits/CalorimeterHits.time',
#  'CalorimeterHits/CalorimeterHits.position.x',
#  'CalorimeterHits/CalorimeterHits.position.y',
#  'CalorimeterHits/CalorimeterHits.position.z',
#  'CalorimeterHits/CalorimeterHits.type',
#  'EFlowNeutralHadron',
#  'EFlowNeutralHadron/EFlowNeutralHadron.type',
#  'EFlowNeutralHadron/EFlowNeutralHadron.energy',
#  'EFlowNeutralHadron/EFlowNeutralHadron.energyError',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.x',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.y',
#  'EFlowNeutralHadron/EFlowNeutralHadron.position.z',
#  'EFlowNeutralHadron/EFlowNeutralHadron.positionError[6]',
#  'EFlowNeutralHadron/EFlowNeutralHadron.iTheta',
#  'EFlowNeutralHadron/EFlowNeutralHadron.phi',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.x',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.y',
#  'EFlowNeutralHadron/EFlowNeutralHadron.directionError.z',
#  'EFlowNeutralHadron/EFlowNeutralHadron.shapeParameters_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.shapeParameters_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.subdetectorEnergies_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.subdetectorEnergies_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.clusters_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.clusters_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.hits_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.hits_end',
#  'EFlowNeutralHadron/EFlowNeutralHadron.particleIDs_begin',
#  'EFlowNeutralHadron/EFlowNeutralHadron.particleIDs_end',
#  '_EFlowNeutralHadron_clusters',
#  '_EFlowNeutralHadron_clusters/_EFlowNeutralHadron_clusters.index',
#  '_EFlowNeutralHadron_clusters/_EFlowNeutralHadron_clusters.collectionID',
#  '_EFlowNeutralHadron_hits',
#  '_EFlowNeutralHadron_hits/_EFlowNeutralHadron_hits.index',
#  '_EFlowNeutralHadron_hits/_EFlowNeutralHadron_hits.collectionID',
#  '_EFlowNeutralHadron_particleIDs',
#  '_EFlowNeutralHadron_particleIDs/_EFlowNeutralHadron_particleIDs.index',
#  '_EFlowNeutralHadron_particleIDs/_EFlowNeutralHadron_particleIDs.collectionID',
#  '_EFlowNeutralHadron_shapeParameters',
#  '_EFlowNeutralHadron_subdetectorEnergies',
#  'EFlowPhoton',
#  'EFlowPhoton/EFlowPhoton.type',
#  'EFlowPhoton/EFlowPhoton.energy',
#  'EFlowPhoton/EFlowPhoton.energyError',
#  'EFlowPhoton/EFlowPhoton.position.x',
#  'EFlowPhoton/EFlowPhoton.position.y',
#  'EFlowPhoton/EFlowPhoton.position.z',
#  'EFlowPhoton/EFlowPhoton.positionError[6]',
#  'EFlowPhoton/EFlowPhoton.iTheta',
#  'EFlowPhoton/EFlowPhoton.phi',
#  'EFlowPhoton/EFlowPhoton.directionError.x',
#  'EFlowPhoton/EFlowPhoton.directionError.y',
#  'EFlowPhoton/EFlowPhoton.directionError.z',
#  'EFlowPhoton/EFlowPhoton.shapeParameters_begin',
#  'EFlowPhoton/EFlowPhoton.shapeParameters_end',
#  'EFlowPhoton/EFlowPhoton.subdetectorEnergies_begin',
#  'EFlowPhoton/EFlowPhoton.subdetectorEnergies_end',
#  'EFlowPhoton/EFlowPhoton.clusters_begin',
#  'EFlowPhoton/EFlowPhoton.clusters_end',
#  'EFlowPhoton/EFlowPhoton.hits_begin',
#  'EFlowPhoton/EFlowPhoton.hits_end',
#  'EFlowPhoton/EFlowPhoton.particleIDs_begin',
#  'EFlowPhoton/EFlowPhoton.particleIDs_end',
#  '_EFlowPhoton_clusters',
#  '_EFlowPhoton_clusters/_EFlowPhoton_clusters.index',
#  '_EFlowPhoton_clusters/_EFlowPhoton_clusters.collectionID',
#  '_EFlowPhoton_hits',
#  '_EFlowPhoton_hits/_EFlowPhoton_hits.index',
#  '_EFlowPhoton_hits/_EFlowPhoton_hits.collectionID',
#  '_EFlowPhoton_particleIDs',
#  '_EFlowPhoton_particleIDs/_EFlowPhoton_particleIDs.index',
#  '_EFlowPhoton_particleIDs/_EFlowPhoton_particleIDs.collectionID',
#  '_EFlowPhoton_shapeParameters',
#  '_EFlowPhoton_subdetectorEnergies',
#  'EFlowTrack',
#  'EFlowTrack/EFlowTrack.type',
#  'EFlowTrack/EFlowTrack.chi2',
#  'EFlowTrack/EFlowTrack.ndf',
#  'EFlowTrack/EFlowTrack.dEdx',
#  'EFlowTrack/EFlowTrack.dEdxError',
#  'EFlowTrack/EFlowTrack.radiusOfInnermostHit',
#  'EFlowTrack/EFlowTrack.subdetectorHitNumbers_begin',
#  'EFlowTrack/EFlowTrack.subdetectorHitNumbers_end',
#  'EFlowTrack/EFlowTrack.trackStates_begin',
#  'EFlowTrack/EFlowTrack.trackStates_end',
#  'EFlowTrack/EFlowTrack.dxQuantities_begin',
#  'EFlowTrack/EFlowTrack.dxQuantities_end',
#  'EFlowTrack/EFlowTrack.trackerHits_begin',
#  'EFlowTrack/EFlowTrack.trackerHits_end',
#  'EFlowTrack/EFlowTrack.tracks_begin',
#  'EFlowTrack/EFlowTrack.tracks_end',
#  '_EFlowTrack_trackerHits',
#  '_EFlowTrack_trackerHits/_EFlowTrack_trackerHits.index',
#  '_EFlowTrack_trackerHits/_EFlowTrack_trackerHits.collectionID',
#  '_EFlowTrack_tracks',
#  '_EFlowTrack_tracks/_EFlowTrack_tracks.index',
#  '_EFlowTrack_tracks/_EFlowTrack_tracks.collectionID',
#  '_EFlowTrack_subdetectorHitNumbers',
#  '_EFlowTrack_trackStates',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.location',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.D0',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.phi',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.omega',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.Z0',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.tanLambda',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.time',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.x',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.y',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.referencePoint.z',
#  '_EFlowTrack_trackStates/_EFlowTrack_trackStates.covMatrix[21]',
#  '_EFlowTrack_dxQuantities',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.type',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.value',
#  '_EFlowTrack_dxQuantities/_EFlowTrack_dxQuantities.error',
#  'EFlowTrack_L',
#  'Electron_objIdx',
#  'Electron_objIdx/Electron_objIdx.index',
#  'Electron_objIdx/Electron_objIdx.collectionID',
#  'Electron_IsolationVar',
#  'EventHeader',
#  'EventHeader/EventHeader.eventNumber',
#  'EventHeader/EventHeader.runNumber',
#  'EventHeader/EventHeader.timeStamp',
#  'EventHeader/EventHeader.weight',
#  'Jet',
#  'Jet/Jet.type',
#  'Jet/Jet.energy',
#  'Jet/Jet.momentum.x',
#  'Jet/Jet.momentum.y',
#  'Jet/Jet.momentum.z',
#  'Jet/Jet.referencePoint.x',
#  'Jet/Jet.referencePoint.y',
#  'Jet/Jet.referencePoint.z',
#  'Jet/Jet.charge',
#  'Jet/Jet.mass',
#  'Jet/Jet.goodnessOfPID',
#  'Jet/Jet.covMatrix[10]',
#  'Jet/Jet.clusters_begin',
#  'Jet/Jet.clusters_end',
#  'Jet/Jet.tracks_begin',
#  'Jet/Jet.tracks_end',
#  'Jet/Jet.particles_begin',
#  'Jet/Jet.particles_end',
#  'Jet/Jet.particleIDs_begin',
#  'Jet/Jet.particleIDs_end',
#  '_Jet_clusters',
#  '_Jet_clusters/_Jet_clusters.index',
#  '_Jet_clusters/_Jet_clusters.collectionID',
#  '_Jet_tracks',
#  '_Jet_tracks/_Jet_tracks.index',
#  '_Jet_tracks/_Jet_tracks.collectionID',
#  '_Jet_particles',
#  '_Jet_particles/_Jet_particles.index',
#  '_Jet_particles/_Jet_particles.collectionID',
#  '_Jet_particleIDs',
#  '_Jet_particleIDs/_Jet_particleIDs.index',
#  '_Jet_particleIDs/_Jet_particleIDs.collectionID',
#  '_Jet_startVertex',
#  '_Jet_startVertex/_Jet_startVertex.index',
#  '_Jet_startVertex/_Jet_startVertex.collectionID',
#  '_Jet_particleIDUsed',
#  '_Jet_particleIDUsed/_Jet_particleIDUsed.index',
#  '_Jet_particleIDUsed/_Jet_particleIDUsed.collectionID',
#  'magFieldBz',
#  'MCRecoAssociations',
#  'MCRecoAssociations/MCRecoAssociations.weight',
#  '_MCRecoAssociations_rec',
#  '_MCRecoAssociations_rec/_MCRecoAssociations_rec.index',
#  '_MCRecoAssociations_rec/_MCRecoAssociations_rec.collectionID',
#  '_MCRecoAssociations_sim',
#  '_MCRecoAssociations_sim/_MCRecoAssociations_sim.index',
#  '_MCRecoAssociations_sim/_MCRecoAssociations_sim.collectionID',
#  'Muon_objIdx',
#  'Muon_objIdx/Muon_objIdx.index',
#  'Muon_objIdx/Muon_objIdx.collectionID',
#  'Muon_IsolationVar',
#  'Particle',
#  'Particle/Particle.PDG',
#  'Particle/Particle.generatorStatus',
#  'Particle/Particle.simulatorStatus',
#  'Particle/Particle.charge',
#  'Particle/Particle.time',
#  'Particle/Particle.mass',
#  'Particle/Particle.vertex.x',
#  'Particle/Particle.vertex.y',
#  'Particle/Particle.vertex.z',
#  'Particle/Particle.endpoint.x',
#  'Particle/Particle.endpoint.y',
#  'Particle/Particle.endpoint.z',
#  'Particle/Particle.momentum.x',
#  'Particle/Particle.momentum.y',
#  'Particle/Particle.momentum.z',
#  'Particle/Particle.momentumAtEndpoint.x',
#  'Particle/Particle.momentumAtEndpoint.y',
#  'Particle/Particle.momentumAtEndpoint.z',
#  'Particle/Particle.spin.x',
#  'Particle/Particle.spin.y',
#  'Particle/Particle.spin.z',
#  'Particle/Particle.colorFlow.a',
#  'Particle/Particle.colorFlow.b',
#  'Particle/Particle.parents_begin',
#  'Particle/Particle.parents_end',
#  'Particle/Particle.daughters_begin',
#  'Particle/Particle.daughters_end',
#  '_Particle_parents',
#  '_Particle_parents/_Particle_parents.index',
#  '_Particle_parents/_Particle_parents.collectionID',
#  '_Particle_daughters',
#  '_Particle_daughters/_Particle_daughters.index',
#  '_Particle_daughters/_Particle_daughters.collectionID',
#  'ParticleIDs',
#  'ParticleIDs/ParticleIDs.type',
#  'ParticleIDs/ParticleIDs.PDG',
#  'ParticleIDs/ParticleIDs.algorithmType',
#  'ParticleIDs/ParticleIDs.likelihood',
#  'ParticleIDs/ParticleIDs.parameters_begin',
#  'ParticleIDs/ParticleIDs.parameters_end',
#  '_ParticleIDs_parameters',
#  'Photon_objIdx',
#  'Photon_objIdx/Photon_objIdx.index',
#  'Photon_objIdx/Photon_objIdx.collectionID',
#  'Photon_IsolationVar',
#  'ReconstructedParticles',
#  'ReconstructedParticles/ReconstructedParticles.type',
#  'ReconstructedParticles/ReconstructedParticles.energy',
#  'ReconstructedParticles/ReconstructedParticles.momentum.x',
#  'ReconstructedParticles/ReconstructedParticles.momentum.y',
#  'ReconstructedParticles/ReconstructedParticles.momentum.z',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.x',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.y',
#  'ReconstructedParticles/ReconstructedParticles.referencePoint.z',
#  'ReconstructedParticles/ReconstructedParticles.charge',
#  'ReconstructedParticles/ReconstructedParticles.mass',
#  'ReconstructedParticles/ReconstructedParticles.goodnessOfPID',
#  'ReconstructedParticles/ReconstructedParticles.covMatrix[10]',
#  'ReconstructedParticles/ReconstructedParticles.clusters_begin',
#  'ReconstructedParticles/ReconstructedParticles.clusters_end',
#  'ReconstructedParticles/ReconstructedParticles.tracks_begin',
#  'ReconstructedParticles/ReconstructedParticles.tracks_end',
#  'ReconstructedParticles/ReconstructedParticles.particles_begin',
#  'ReconstructedParticles/ReconstructedParticles.particles_end',
#  'ReconstructedParticles/ReconstructedParticles.particleIDs_begin',
#  'ReconstructedParticles/ReconstructedParticles.particleIDs_end',
#  '_ReconstructedParticles_clusters',
#  '_ReconstructedParticles_clusters/_ReconstructedParticles_clusters.index',
#  '_ReconstructedParticles_clusters/_ReconstructedParticles_clusters.collectionID',
#  '_ReconstructedParticles_tracks',
#  '_ReconstructedParticles_tracks/_ReconstructedParticles_tracks.index',
#  '_ReconstructedParticles_tracks/_ReconstructedParticles_tracks.collectionID',
#  '_ReconstructedParticles_particles',
#  '_ReconstructedParticles_particles/_ReconstructedParticles_particles.index',
#  '_ReconstructedParticles_particles/_ReconstructedParticles_particles.collectionID',
#  '_ReconstructedParticles_particleIDs',
#  '_ReconstructedParticles_particleIDs/_ReconstructedParticles_particleIDs.index',
#  '_ReconstructedParticles_particleIDs/_ReconstructedParticles_particleIDs.collectionID',
#  '_ReconstructedParticles_startVertex',
#  '_ReconstructedParticles_startVertex/_ReconstructedParticles_startVertex.index',
#  '_ReconstructedParticles_startVertex/_ReconstructedParticles_startVertex.collectionID',
#  '_ReconstructedParticles_particleIDUsed',
#  '_ReconstructedParticles_particleIDUsed/_ReconstructedParticles_particleIDUsed.index',
#  '_ReconstructedParticles_particleIDUsed/_ReconstructedParticles_particleIDUsed.collectionID',
#  'TrackerHits',
#  'TrackerHits/TrackerHits.cellID',
#  'TrackerHits/TrackerHits.type',
#  'TrackerHits/TrackerHits.quality',
#  'TrackerHits/TrackerHits.time',
#  'TrackerHits/TrackerHits.eDep',
#  'TrackerHits/TrackerHits.eDepError',
#  'TrackerHits/TrackerHits.position.x',
#  'TrackerHits/TrackerHits.position.y',
#  'TrackerHits/TrackerHits.position.z',
#  'TrackerHits/TrackerHits.covMatrix[6]',
#  'TrackerHits/TrackerHits.rawHits_begin',
#  'TrackerHits/TrackerHits.rawHits_end',
#  '_TrackerHits_rawHits',
#  '_TrackerHits_rawHits/_TrackerHits_rawHits.index',
#  '_TrackerHits_rawHits/_TrackerHits_rawHits.collectionID']
